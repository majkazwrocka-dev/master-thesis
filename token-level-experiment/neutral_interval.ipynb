# %% [markdown]
# # Data exploration - looking for neutral interval

# %%
import json

# %%
file_path = "../data/eng-houn.json"
with open(file_path, "r") as f:
    data = json.load(f)

# %%
example_sentence = data["sentences"][38]
sentence_text = example_sentence["text"]

words_with_sentiment = []
for concept in example_sentence.get("concepts", []):
    if "sentiment" in concept:
        sentiment = concept["sentiment"]
        clemma = concept.get("clemma", "")
        words_with_sentiment.append((clemma, sentiment))

sentence_text, words_with_sentiment
# Out:
# ("'Has anything escaped me?' I asked, with some self-importance. ",
#  [('escape', -34.0)])

# %%
concept_sentiment_words = []

for sentence in data.get("sentences", []):
    for concept in sentence.get("concepts", []):
        if "sentiment" in concept:
            clemma = concept.get("clemma")
            sentiment_value = concept["sentiment"]
            if clemma:
                concept_sentiment_words.append((clemma, sentiment_value))

concept_sentiment_dict = {}
for clemma, sentiment in concept_sentiment_words:
    if sentiment not in concept_sentiment_dict:
        concept_sentiment_dict[sentiment] = set()
    concept_sentiment_dict[sentiment].add(clemma)

concept_sentiment_examples = {
    sentiment: sorted(clemmata)[:5] for sentiment, clemmata in concept_sentiment_dict.items()
}

concept_sentiment_examples
# Out:
# {-64.0: ['abhor', 'agitated', 'agitation', 'agonize', 'agony'],
#  64.0: ['admirable', 'affection', 'beautiful', 'beautifully', 'beauty'],
#  34.0: ['able', 'accomplish', 'achievement', 'admirable', 'admiration'],
#  95.0: ['best', 'brilliant', 'excellent', 'exultation', 'formidable'],
#  0.0: ['Sherlock Holmes', 'a few', 'a good deal', 'a great deal', 'ability'],
#  -34.0: ['abandon', 'abet', 'abortive', 'absence', 'absent-minded'],
#  -95.0: ['despair', 'diabolical', 'evil', 'fiendish', 'foul'],
#  -22.0: ['careless', 'hesitate'],
#  21.0: ['safe'],
#  19.0: ['convenient'],
#  -47.0: ['by thunder', 'thunder'],
#  -49.0: ['by thunder'],
#  -25.0: ['hesitation', 'use'],
#  -44.0: ['thunder'],
#  60.0: ['come along', 'keen', 'rich', 'unwarlike'],
#  -31.0: ['cry', 'no'],
#  32.0: ['power'],
#  72.0: ['play'],
#  -77.0: ['game'],
#  -20.0: ['abandon', 'barren', 'blot out', 'blur', 'body'],
#  20.0: ['able', 'advice', 'animation', 'assure', 'atone'],
#  44.0: ['natural', 'one'],
#  48.0: ['mind'],
#  -5.0: ['checkmate'],
#  43.0: ['well'],
#  38.0: ['keen'],
#  -58.0: ['stick'],
#  -61.0: ['starved', 'stick at nothing'],
#  -62.0: ['stick at nothing', 'tear'],
#  1.0: ['now'],
#  -46.0: ['by thunder', 'in the way'],
#  -53.0: ['gloom'],
#  37.0: ['chance'],
#  34.35: ['deep'],
#  1.4000000000000001: ['do'],
#  41.175: ['friend'],
#  30.0: ['beam', 'sir'],
#  35.0: ['patient'],
#  20.125: ['answer'],
#  8.5: ['bring'],
#  -50.0: ['loom'],
#  59.0: ["at one's fingers' ends", 'house', 'truthful'],
#  29.0: ['i'],
#  28.299999999999997: ['idea'],
#  61.0: ['kind'],
#  74.0: ['dare say'],
#  -80.0: ['done to death', 'hatred'],
#  28.0: ['know'],
#  46.0: ['help'],
#  -33.0: ['unable'],
#  -78.0: ['done to death', 'ride roughshod over'],
#  -38.0: ['swarm'],
#  27.0: ['knowing'],
#  2.4: ['manner'],
#  11.3: ['occupy'],
#  11.85: ['think'],
#  13.0: ['more'],
#  1.2: ['come'],
#  47.0: ['by heaven', 'lay the ghost'],
#  -100.0: ['spasm'],
#  -6.399999999999999: ['help'],
#  -30.5: ['cry'],
#  39.0: ['promise'],
#  -3.0: ['rueful'],
#  45.0: ['plan of campaign'],
#  12.0: ['sir'],
#  -19.5: ['supreme'],
#  100.0: ['real'],
#  -63.0: ['anxiety'],
#  -94.0: ['pistolling'],
#  58.0: ['complete'],
#  70.0: ['sir']}

# %%
neutral_clemmata = []

for clemma, sentiment in concept_sentiment_words:
    if -10 <= sentiment <= 10:
        neutral_clemmata.append((clemma, sentiment))

# Sort by sentiment value for better readability
neutral_clemmata_sorted = sorted(neutral_clemmata, key=lambda x: x[1])

neutral_clemmata_sorted
# Out:
# [('help', -6.399999999999999),
#  ('checkmate', -5.0),
#  ('rueful', -3.0),
#  ('a great deal', 0.0),
#  ('deduction', 0.0),
#  ('pass through', 0.0),
#  ('positively', 0.0),
#  ('evil', 0.0),
#  ('canada', 0.0),
#  ('opinion', 0.0),
#  ('him', 0.0),
#  ('be', 0.0),
#  ('shadow', 0.0),
#  ('look', 0.0),
#  ('impossible', 0.0),
#  ('no one', 0.0),
#  ('my', 0.0),
#  ('ruin', 0.0),
#  ('sombre', 0.0),
#  ('i', 0.0),
#  ('stare', 0.0),
#  ('tap', 0.0),
#  ('gloomy', 0.0),
#  ('fight', 0.0),
#  ('defy', 0.0),
#  ('mysterious', 0.0),
#  ('motionless', 0.0),
#  ('creep', 0.0),
#  ('noiselessly', 0.0),
#  ('peep', 0.0),
#  ('rigid', 0.0),
#  ('blackness', 0.0),
#  ('intently', 0.0),
#  ('deep', 0.0),
#  ('groan', 0.0),
#  ('impatient', 0.0),
#  ('gesture', 0.0),
#  ('instantly', 0.0),
#  ('make', 0.0),
#  ('way', 0.0),
#  ('come', 0.0),
#  ('stealthy', 0.0),
#  ('pass', 0.0),
#  ('return', 0.0),
#  ('secret', 0.0),
#  ('go on', 0.0),
#  ('furnish', 0.0),
#  ('make', 0.0),
#  ('found', 0.0),
#  ('make', 0.0),
#  ('have', 0.0),
#  ('surprise', 0.0),
#  ('not', 0.0),
#  ('have', 0.0),
#  ('clear', 0.0),
#  ('judge', 0.0),
#  ('adventure', 0.0),
#  ('examine', 0.0),
#  ('stare', 0.0),
#  ('intently', 0.0),
#  ('have', 0.0),
#  ('notice', 0.0),
#  ('command', 0.0),
#  ('tree', 0.0),
#  ('enable', 0.0),
#  ('look', 0.0),
#  ('only', 0.0),
#  ('distant', 0.0),
#  ('obtain', 0.0),
#  ('serve', 0.0),
#  ('purpose', 0.0),
#  ('look out', 0.0),
#  ('very', 0.0),
#  ('dark', 0.0),
#  ('hardly', 0.0),
#  ('imagine', 0.0),
#  ('strike', 0.0),
#  ('possible', 0.0),
#  ('intrigue', 0.0),
#  ('stealthy', 0.0),
#  ('account for', 0.0),
#  ('striking', 0.0),
#  ('very', 0.0),
#  ('have', 0.0),
#  ('return', 0.0),
#  ('clandestine', 0.0),
#  ('suspicion', 0.0),
#  ('result', 0.0),
#  ('true', 0.0),
#  ('responsibility', 0.0),
#  ('explain', 0.0),
#  ('more than', 0.0),
#  ('have', 0.0),
#  ('know', 0.0),
#  ('have', 0.0),
#  ('come', 0.0),
#  ('perhaps', 0.0),
#  ('suggest', 0.0),
#  ('every night', 0.0),
#  ('perhaps', 0.0),
#  ('do', 0.0),
#  ('do', 0.0),
#  ('exactly', 0.0),
#  ('suggest', 0.0),
#  ('do', 0.0),
#  ('do', 0.0),
#  ('pass', 0.0),
#  ('evident', 0.0),
#  ('adventure', 0.0),
#  ('quiet', 0.0),
#  ('soon', 0.0),
#  ('evident', 0.0),
#  ('friend', 0.0),
#  ('have', 0.0),
#  ('large', 0.0),
#  ('idea', 0.0),
#  ('restore', 0.0),
#  ('renovate', 0.0),
#  ('refurnish', 0.0),
#  ('make', 0.0),
#  ('clear', 0.0),
#  ('not', 0.0),
#  ('lady', 0.0),
#  ('willing', 0.0),
#  ('infatuated', 0.0),
#  ('yet', 0.0),
#  ('not', 0.0),
#  ('quite', 0.0),
#  ('break', 0.0),
#  ('unexpected', 0.0),
#  ('cause', 0.0),
#  ('friend', 0.0),
#  ('considerable', 0.0),
#  ('come', 0.0),
#  ('curious', 0.0),
#  ('well', 0.0),
#  ('know', 0.0),
#  ('earnestly', 0.0),
#  ('insist', 0.0),
#  ('understand', 0.0),
#  ('sure', 0.0),
#  ('wish', 0.0),
#  ('do', 0.0),
#  ('have', 0.0),
#  ('allow', 0.0),
#  ('imagine', 0.0),
#  ('return', 0.0),
#  ('thought', 0.0),
#  ('at once', 0.0),
#  ('come', 0.0),
#  ('perhaps', 0.0),
#  ('at once', 0.0),
#  ('lady', 0.0),
#  ('clear', 0.0),
#  ('understanding', 0.0),
#  ('make', 0.0),
#  ('earnest', 0.0),
#  ('intently', 0.0),
#  ('dissent', 0.0),
#  ('very much', 0.0),
#  ('intimate', 0.0),
#  ('clear', 0.0),
#  ('duty', 0.0),
#  ('let', 0.0),
#  ('confess', 0.0),
#  ('away', 0.0),
#  ('use', 0.0),
#  ('agree', 0.0),
#  ('nothing', 0.0),
#  ('do', 0.0),
#  ('friend', 0.0),
#  ('lady', 0.0),
#  ('deeply', 0.0),
#  ('aware', 0.0),
#  ('very much', 0.0),
#  ('strain', 0.0),
#  ('away', 0.0),
#  ('avert', 0.0),
#  ('stoop', 0.0),
#  ('spring', 0.0),
#  ('apart', 0.0),
#  ('cause', 0.0),
#  ('interruption', 0.0),
#  ('wildly', 0.0),
#  ('gesticulate', 0.0),
#  ('dance', 0.0),
#  ('excitement', 0.0),
#  ('imagine', 0.0),
#  ('refuse', 0.0),
#  ('accept', 0.0),
#  ('lady', 0.0),
#  ('peremptory', 0.0),
#  ('way', 0.0),
#  ('irresolute', 0.0),
#  ('lady', 0.0),
#  ('come', 0.0),
#  ('hang', 0.0),
#  ('imagine', 0.0),
#  ('deeply', 0.0),
#  ('intimate', 0.0),
#  ('friend', 0.0),
#  ('knowledge', 0.0),
#  ('do', 0.0),
#  ("wits' end", 0.0),
#  ('hullo', 0.0),
#  ('explain', 0.0),
#  ('everything', 0.0),
#  ('find', 0.0),
#  ('impossible', 0.0),
#  ('blaze', 0.0),
#  ('frankness', 0.0),
#  ('laugh', 0.0),
#  ('at last', 0.0),
#  ('think', 0.0),
#  ('do', 0.0),
#  ('woo', 0.0),
#  ('woo', 0.0),
#  ('brother', 0.0),
#  ('well', 0.0),
#  ('come out', 0.0),
#  ('yes', 0.0),
#  ('strike', 0.0),
#  ('brother', 0.0),
#  ('dare', 0.0),
#  ('think', 0.0),
#  ('sane', 0.0),
#  ('strait-jacket', 0.0),
#  ('matter', 0.0),
#  ('prevent', 0.0),
#  ('husband', 0.0),
#  ('what', 0.0),
#  ('have', 0.0),
#  ('he', 0.0),
#  ('me', 0.0),
#  ('never', 0.0),
#  ('let', 0.0),
#  ('know', 0.0),
#  ('never', 0.0),
#  ('let', 0.0),
#  ('have', 0.0),
#  ('get together', 0.0),
#  ('let', 0.0),
#  ('either', 0.0),
#  ('never', 0.0),
#  ('leave', 0.0),
#  ('be', 0.0),
#  ('want', 0.0),
#  ('way', 0.0),
#  ('work', 0.0),
#  ('marry', 0.0),
#  ('answer', 0.0),
#  ('come', 0.0),
#  ('lady', 0.0),
#  ('do', 0.0),
#  ('like', 0.0),
#  ('know', 0.0),
#  ('feeling', 0.0),
#  ('hope', 0.0),
#  ('make', 0.0),
#  ('answer', 0.0),
#  ('perhaps', 0.0),
#  ('see', 0.0),
#  ('badly', 0.0),
#  ('puzzle', 0.0),
#  ('hope', 0.0),
#  ('try', 0.0),
#  ('completely', 0.0),
#  ('puzzle', 0.0),
#  ('friend', 0.0),
#  ('fortune', 0.0),
#  ('know', 0.0),
#  ('brusquely', 0.0),
#  ('lady', 0.0),
#  ('lady', 0.0),
#  ('amazing', 0.0),
#  ('conjecture', 0.0),
#  ('at rest', 0.0),
#  ('upshot', 0.0),
#  ('breach', 0.0),
#  ('quite', 0.0),
#  ('make', 0.0),
#  ('handsome', 0.0),
#  ('give', 0.0),
#  ('everything', 0.0),
#  ('understand', 0.0),
#  ('value', 0.0),
#  ('lonely', 0.0),
#  ('companion', 0.0),
#  ('thought', 0.0),
#  ('lose', 0.0),
#  ('give', 0.0),
#  ('do', 0.0),
#  ('take away', 0.0),
#  ('responsible for', 0.0),
#  ('recognize', 0.0),
#  ('imagine', 0.0),
#  ('rather', 0.0),
#  ('promise', 0.0),
#  ('let', 0.0),
#  ('cultivate', 0.0),
#  ('lady', 0.0),
#  ('promise', 0.0),
#  ('mystery', 0.0),
#  ('clear up', 0.0),
#  ('bog', 0.0),
#  ('know', 0.0),
#  ('mystery', 0.0),
#  ('secret', 0.0),
#  ('not', 0.0),
#  ('not', 0.0),
#  ('work', 0.0),
#  ('thoroughly', 0.0),
#  ('work', 0.0),
#  ('work', 0.0),
#  ('entirely', 0.0),
#  ('in truth', 0.0),
#  ('draw blank', 0.0),
#  ('sir', 0.0),
#  ('no', 0.0),
#  ('chime', 0.0),
#  ('not', 0.0),
#  ('determine', 0.0),
#  ('try', 0.0),
#  ('make', 0.0),
#  ('incredible', 0.0),
#  ('slowly', 0.0),
#  ('crawl', 0.0),
#  ('interest', 0.0),
#  ('keenly', 0.0),
#  ('alert', 0.0),
#  ('creak', 0.0),
#  ('stealthily', 0.0),
#  ('die away', 0.0),
#  ('gently', 0.0),
#  ('open', 0.0),
#  ('pursuit', 0.0),
#  ('darkness', 0.0),
#  ('in darkness', 0.0),
#  ('softly', 0.0),
#  ('steal', 0.0),
#  ('figure', 0.0),
#  ('light', 0.0),
#  ('darkness', 0.0),
#  ('yellow', 0.0),
#  ('gloom', 0.0),
#  ('cautiously', 0.0),
#  ('try', 0.0),
#  ('every', 0.0),
#  ('precaution', 0.0),
#  ('snap', 0.0),
#  ('creak', 0.0),
#  ('however', 0.0),
#  ('entirely', 0.0),
#  ('do', 0.0),
#  ('reach', 0.0),
#  ('peep', 0.0),
#  ('find', 0.0),
#  ('exactly', 0.0),
#  ('direct', 0.0),
#  ('way', 0.0),
#  ('natural', 0.0),
#  ('do', 0.0),
#  ('breath', 0.0),
#  ('trembling', 0.0),
#  ('dark', 0.0),
#  ('glare', 0.0),
#  ('full', 0.0),
#  ('astonishment', 0.0),
#  ('sir', 0.0),
#  ('do', 0.0),
#  ('sir', 0.0),
#  ('great', 0.0),
#  ('hardly', 0.0),
#  ('shadow', 0.0),
#  ('shaking', 0.0),
#  ('spring up', 0.0),
#  ('sir', 0.0),
#  ('yes', 0.0),
#  ('sir', 0.0),
#  ('sir', 0.0),
#  ('sternly', 0.0),
#  ('have', 0.0),
#  ('truth', 0.0),
#  ('lie', 0.0),
#  ('do', 0.0),
#  ('way', 0.0),
#  ('wring', 0.0),
#  ('together', 0.0),
#  ('doubt', 0.0),
#  ('do', 0.0),
#  ('sir', 0.0),
#  ('sir', 0.0),
#  ('secret', 0.0),
#  ('concern', 0.0),
#  ('try', 0.0),
#  ('keep', 0.0),
#  ('sudden', 0.0),
#  ('idea', 0.0),
#  ('let', 0.0),
#  ('do', 0.0),
#  ('darkness', 0.0),
#  ('discern', 0.0),
#  ('black', 0.0),
#  ('moon', 0.0),
#  ('yellow', 0.0),
#  ('light', 0.0),
#  ('suddenly', 0.0),
#  ('glow', 0.0),
#  ('steadily', 0.0),
#  ('black', 0.0),
#  ('cry', 0.0),
#  ('sir', 0.0),
#  ('assure', 0.0),
#  ('light', 0.0),
#  ('cry', 0.0),
#  ('baronet', 0.0),
#  ('deny', 0.0),
#  ('business', 0.0),
#  ('leave', 0.0),
#  ('right away', 0.0),
#  ('find', 0.0),
#  ('bulky', 0.0),
#  ('do', 0.0),
#  ('let', 0.0),
#  ('ready', 0.0),
#  ('bring', 0.0),
#  ('escaped', 0.0),
#  ('truth', 0.0),
#  ('stealthy', 0.0),
#  ('expedition', 0.0),
#  ('amazement', 0.0),
#  ('possible', 0.0),
#  ('stolidly', 0.0),
#  ('young', 0.0),
#  ('everything', 0.0),
#  ('think', 0.0),
#  ('do', 0.0),
#  ('grow', 0.0),
#  ('companion', 0.0),
#  ('sink', 0.0),
#  ('only', 0.0),
#  ('snatch', 0.0),
#  ('scaffold', 0.0),
#  ('sir', 0.0),
#  ('boy', 0.0),
#  ('sir', 0.0),
#  ('know', 0.0),
#  ('drag', 0.0),
#  ('feed', 0.0),
#  ('take in', 0.0),
#  ('return', 0.0),
#  ('think', 0.0),
#  ('lay', 0.0),
#  ('hue and cry', 0.0),
#  ('still', 0.0),
#  ('every', 0.0),
#  ('whole', 0.0),
#  ('truth', 0.0),
#  ('christian', 0.0),
#  ('matter', 0.0),
#  ('lie', 0.0),
#  ('sake', 0.0),
#  ('do', 0.0),
#  ('word', 0.0),
#  ('intense', 0.0),
#  ('earnestness', 0.0),
#  ('conviction', 0.0),
#  ('true', 0.0),
#  ('every', 0.0),
#  ('blame', 0.0),
#  ('forget', 0.0),
#  ('far', 0.0),
#  ('matter', 0.0),
#  ('talk about', 0.0),
#  ('when', 0.0),
#  ('fling', 0.0),
#  ('open', 0.0),
#  ('beat', 0.0),
#  ('away', 0.0),
#  ('black', 0.0),
#  ('yellow', 0.0),
#  ('light', 0.0),
#  ('think', 0.0),
#  ('think', 0.0),
#  ('hardly', 0.0),
#  ('thought', 0.0),
#  ('do', 0.0),
#  ('thought', 0.0),
#  ('make', 0.0),
#  ('adventure', 0.0),
#  ('come', 0.0),
#  ('revolver', 0.0),
#  ('dark', 0.0),
#  ('dull', 0.0),
#  ('wind', 0.0),
#  ('smell', 0.0),
#  ('damp', 0.0),
#  ('moon', 0.0),
#  ('sky', 0.0),
#  ('rain', 0.0),
#  ('steadily', 0.0),
#  ('arm', 0.0),
#  ('have', 0.0),
#  ('rapidly', 0.0),
#  ('we', 0.0),
#  ('take', 0.0),
#  ('mercy', 0.0),
#  ('answer', 0.0),
#  ('gloom', 0.0),
#  ('strange', 0.0),
#  ('cry', 0.0),
#  ('great', 0.0),
#  ('as if', 0.0),
#  ('deep', 0.0),
#  ('come with', 0.0),
#  ('come through', 0.0),
#  ('die away', 0.0),
#  ('and then', 0.0),
#  ('wild', 0.0),
#  ('again and again', 0.0),
#  ('darkness', 0.0),
#  ('know', 0.0),
#  ('have', 0.0),
#  ('close in', 0.0),
#  ('strain', 0.0),
#  ('come', 0.0),
#  ('cry', 0.0),
#  ('seize', 0.0),
#  ('ignorant', 0.0),
#  ('cry', 0.0),
#  ('a few', 0.0),
#  ('away', 0.0),
#  ('think', 0.0),
#  ('at last', 0.0),
#  ('great', 0.0),
#  ('think', 0.0),
#  ('cry', 0.0),
#  ('strange', 0.0),
#  ('truth', 0.0),
#  ('possible', 0.0),
#  ('cause', 0.0),
#  ('cry', 0.0),
#  ('fit', 0.0),
#  ('think', 0.0),
#  ('cold', 0.0),
#  ('think', 0.0),
#  ('advise', 0.0),
#  ('do', 0.0),
#  ('come', 0.0),
#  ('get', 0.0),
#  ('do', 0.0),
#  ('likely', 0.0),
#  ('come on', 0.0),
#  ('see through', 0.0),
#  ('stumble', 0.0),
#  ('black', 0.0),
#  ('yellow', 0.0),
#  ('steadily', 0.0),
#  ('pitch-dark', 0.0),
#  ('glimmer', 0.0),
#  ('away', 0.0),
#  ('know', 0.0),
#  ('yellow', 0.0),
#  ('do', 0.0),
#  ('let us see', 0.0),
#  ('animal', 0.0),
#  ('passion', 0.0),
#  ('have', 0.0),
#  ('give', 0.0),
#  ('have', 0.0),
#  ('think', 0.0),
#  ('darkness', 0.0),
#  ('spring', 0.0),
#  ('scream', 0.0),
#  ('shelter', 0.0),
#  ('spring', 0.0),
#  ('lucky', 0.0),
#  ('by chance', 0.0),
#  ('great', 0.0),
#  ('spring', 0.0),
#  ('lucky', 0.0),
#  ('bring', 0.0),
#  ('defend', 0.0),
#  ('shoot', 0.0),
#  ('run away', 0.0),
#  ('fair', 0.0),
#  ('soon', 0.0),
#  ('swiftly', 0.0),
#  ('completely', 0.0),
#  ('grow', 0.0),
#  ('disappear', 0.0),
#  ('assure', 0.0),
#  ('judge', 0.0),
#  ('thin', 0.0),
#  ('fold', 0.0),
#  ('disappear', 0.0),
#  ('surprise', 0.0),
#  ('point out', 0.0),
#  ('i', 0.0),
#  ('wish', 0.0),
#  ('away', 0.0),
#  ('go in', 0.0),
#  ('nerve', 0.0),
#  ('quiver', 0.0),
#  ('cry', 0.0),
#  ('family', 0.0),
#  ('mood', 0.0),
#  ('fresh', 0.0),
#  ('adventure', 0.0),
#  ('lonely', 0.0),
#  ('strange', 0.0),
#  ('give', 0.0),
#  ('well', 0.0),
#  ('perhaps', 0.0),
#  ('like', 0.0),
#  ('have', 0.0),
#  ('missing', 0.0),
#  ('have', 0.0),
#  ('not', 0.0),
#  ('have', 0.0),
#  ('prisoner', 0.0),
#  ('adventure', 0.0),
#  ('very well', 0.0),
#  ('let', 0.0),
#  ('find', 0.0),
#  ('very much', 0.0),
#  ('mystery', 0.0),
#  ('strange', 0.0),
#  ('inscrutable', 0.0),
#  ('perhaps', 0.0),
#  ('come down', 0.0),
#  ('compel', 0.0),
#  ('arrive at', 0.0),
#  ('proceed', 0.0),
#  ('strange', 0.0),
#  ('dull', 0.0),
#  ('foggy', 0.0),
#  ('excitement', 0.0),
#  ('impend', 0.0),
#  ('have', 0.0),
#  ('not', 0.0),
#  ('incident', 0.0),
#  ('exactly', 0.0),
#  ('strange', 0.0),
#  ('incredible', 0.0),
#  ('hound', 0.0),
#  ('fill', 0.0),
#  ('not', 0.0),
#  ('have', 0.0),
#  ('nothing', 0.0),
#  ('fall in', 0.0),
#  ('do', 0.0),
#  ('not', 0.0),
#  ('mere', 0.0),
#  ('listen', 0.0),
#  ('agent', 0.0),
#  ('moor', 0.0),
#  ('suppose', 0.0),
#  ('hound', 0.0),
#  ('loose', 0.0),
#  ('explain', 0.0),
#  ('everything', 0.0),
#  ('hound', 0.0),
#  ('conceal', 0.0),
#  ('food', 0.0),
#  ('come', 0.0),
#  ('explanation', 0.0),
#  ('hound', 0.0),
#  ('agency', 0.0),
#  ('moor', 0.0),
#  ('real', 0.0),
#  ('work', 0.0),
#  ('follow', 0.0),
#  ('stranger', 0.0),
#  ('true', 0.0),
#  ('have', 0.0),
#  ('glance', 0.0),
#  ('thing', 0.0),
#  ('ready', 0.0),
#  ('swear', 0.0),
#  ('meet', 0.0),
#  ('neighbour', 0.0),
#  ('no one', 0.0),
#  ('leave behind', 0.0),
#  ('stranger', 0.0),
#  ('dogging', 0.0),
#  ('stranger', 0.0),
#  ('dogged', 0.0),
#  ('never', 0.0),
#  ('find', 0.0),
#  ('at last', 0.0),
#  ('purpose', 0.0),
#  ('devote', 0.0),
#  ('energy', 0.0),
#  ('impulse', 0.0),
#  ('plan', 0.0),
#  ('play', 0.0),
#  ('speak', 0.0),
#  ('little', 0.0),
#  ('possible', 0.0),
#  ('strangely', 0.0),
#  ('shake', 0.0),
#  ('have', 0.0),
#  ('have', 0.0),
#  ('good', 0.0),
#  ('idea', 0.0),
#  ('open', 0.0),
#  ('think', 0.0),
#  ('free will', 0.0),
#  ('beg', 0.0),
#  ('surprise', 0.0),
#  ('come', 0.0),
#  ('learn', 0.0),
#  ('very much', 0.0),
#  ('free will', 0.0),
#  ('help', 0.0),
#  ('think', 0.0),
#  ('lonely', 0.0),
#  ('want', 0.0),
#  ('no', 0.0),
#  ('anyone', 0.0),
#  ('he', 0.0),
#  ('be', 0.0),
#  ('under lock and key', 0.0),
#  ('no', 0.0),
#  ('sir', 0.0),
#  ('solemn', 0.0),
#  ('necessary', 0.0),
#  ('way', 0.0),
#  ('god', 0.0),
#  ('beg', 0.0),
#  ('let', 0.0),
#  ('know', 0.0),
#  ('ready', 0.0),
#  ('get', 0.0),
#  ('beg', 0.0),
#  ('do', 0.0),
#  ('want', 0.0),
#  ('true', 0.0),
#  ('heart', 0.0),
#  ('guess', 0.0),
#  ('feel', 0.0),
#  ('give up', 0.0),
#  ('like', 0.0),
#  ('do', 0.0),
#  ('in return', 0.0),
#  ('know', 0.0),
#  ('perhaps', 0.0),
#  ('know', 0.0),
#  ('know', 0.0),
#  ('know', 0.0),
#  ('yes', 0.0),
#  ('give', 0.0),
#  ('give', 0.0),
#  ('know', 0.0),
#  ('have', 0.0),
#  ('well', 0.0),
#  ('have', 0.0),
#  ('great', 0.0),
#  ('public', 0.0),
#  ('take notice', 0.0),
#  ('well', 0.0),
#  ('well', 0.0),
#  ('find', 0.0),
#  ('ash', 0.0),
#  ('great', 0.0),
#  ('char', 0.0),
#  ('black', 0.0),
#  ('please', 0.0),
#  ('please', 0.0),
#  ('have got', 0.0),
#  ('crumble', 0.0),
#  ('take notice', 0.0),
#  ('well', 0.0),
#  ('notice', 0.0),
#  ('come', 0.0),
#  ('sir', 0.0),
#  ('have', 0.0),
#  ('lady', 0.0),
#  ('know', 0.0),
#  ('understand', 0.0),
#  ('conceal', 0.0),
#  ('important', 0.0),
#  ('sir', 0.0),
#  ('immediately', 0.0),
#  ('then again', 0.0),
#  ('master', 0.0),
#  ('carefully', 0.0),
#  ('lady', 0.0),
#  ('rake up', 0.0),
#  ('think', 0.0),
#  ('sir', 0.0),
#  ('think', 0.0),
#  ('think', 0.0),
#  ('new', 0.0),
#  ('light', 0.0),
#  ('black', 0.0),
#  ('think', 0.0),
#  ('l.l', 0.0),
#  ('whole', 0.0),
#  ('know', 0.0),
#  ('have', 0.0),
#  ('find', 0.0),
#  ('think', 0.0),
#  ('do', 0.0),
#  ('know', 0.0),
#  ('at once', 0.0),
#  ('give', 0.0),
#  ('i', 0.0),
#  ('at once', 0.0),
#  ('evident', 0.0),
#  ('busy', 0.0),
#  ('have', 0.0),
#  ('supply', 0.0),
#  ('hardly', 0.0),
#  ('faculty', 0.0),
#  ('new', 0.0),
#  ('arrest', 0.0),
#  ('attention', 0.0),
#  ('interest', 0.0),
#  ('wish', 0.0),
#  ('all', 0.0),
#  ('rustle', 0.0),
#  ('drip', 0.0),
#  ('cold', 0.0),
#  ('moor', 0.0),
#  ('fellow', 0.0),
#  ('suffer', 0.0),
#  ('something', 0.0),
#  ('also', 0.0),
#  ('deluge', 0.0),
#  ('unseen', 0.0),
#  ('watcher', 0.0),
#  ('sodden', 0.0),
#  ('moor', 0.0),
#  ('full', 0.0),
#  ('my', 0.0),
#  ('face', 0.0),
#  ('god', 0.0),
#  ('those', 0.0),
#  ('wander', 0.0),
#  ('great', 0.0),
#  ('mire', 0.0),
#  ('even', 0.0),
#  ('morass', 0.0),
#  ('find', 0.0),
#  ('watcher', 0.0),
#  ('craggy', 0.0),
#  ('down', 0.0),
#  ('squall', 0.0),
#  ('drift', 0.0),
#  ('heavy', 0.0),
#  ('hang', 0.0),
#  ('low', 0.0),
#  ('trail', 0.0),
#  ('grey', 0.0),
#  ('hollow', 0.0),
#  ('sign', 0.0),
#  ('human', 0.0),
#  ('save', 0.0),
#  ('prehistoric', 0.0),
#  ('hut', 0.0),
#  ('lonely', 0.0),
#  ('rough', 0.0),
#  ('moorland', 0.0),
#  ('very', 0.0),
#  ('day', 0.0),
#  ('he', 0.0),
#  ('not', 0.0),
#  ('see', 0.0),
#  ('how', 0.0),
#  ('we', 0.0),
#  ('be', 0.0),
#  ('hardly a', 0.0),
#  ('insist', 0.0),
#  ('me', 0.0),
#  ('lift', 0.0),
#  ('homewards', 0.0),
#  ('never', 0.0),
#  ('give', 0.0),
#  ('fancy', 0.0),
#  ('jolt', 0.0),
#  ('rough', 0.0),
#  ('suppose', 0.0),
#  ('hardly', 0.0),
#  ('think', 0.0),
#  ('answer', 0.0),
#  ('gentry', 0.0),
#  ('add', 0.0),
#  ('marry', 0.0),
#  ('come', 0.0),
#  ('prove', 0.0),
#  ('entirely', 0.0),
#  ('have', 0.0),
#  ('perhaps', 0.0),
#  ('fancy', 0.0),
#  ('affair', 0.0),
#  ('allow', 0.0),
#  ('go', 0.0),
#  ('do', 0.0),
#  ('enable', 0.0),
#  ('give', 0.0),
#  ('set up', 0.0),
#  ('want', 0.0),
#  ('know', 0.0),
#  ('satisfy', 0.0),
#  ('curiosity', 0.0),
#  ('take', 0.0),
#  ('find', 0.0),
#  ('equivocal', 0.0),
#  ('make', 0.0),
#  ('chain', 0.0),
#  ('mystery', 0.0),
#  ('develop', 0.0),
#  ('serpent', 0.0),
#  ('have', 0.0),
#  ('give', 0.0),
#  ('strong', 0.0),
#  ('bring', 0.0),
#  ('well', 0.0),
#  ('know', 0.0),
#  ('hope', 0.0),
#  ('bring', 0.0),
#  ('nothing', 0.0),
#  ('think', 0.0),
#  ('know', 0.0),
#  ('know', 0.0),
#  ('in hiding', 0.0),
#  ('he', 0.0),
#  ('passion', 0.0),
#  ('earnestness', 0.0),
#  ('have', 0.0),
#  ('no', 0.0),
#  ('interest', 0.0),
#  ('master', 0.0),
#  ('i', 0.0),
#  ('come', 0.0),
#  ('no', 0.0),
#  ('frankly', 0.0),
#  ("n't", 0.0),
#  ('barrymore', 0.0),
#  ('outburst', 0.0),
#  ('cry', 0.0),
#  ('swear', 0.0),
#  ('very', 0.0),
#  ('way', 0.0),
#  ('watch', 0.0),
#  ('wait', 0.0),
#  ('hide out', 0.0),
#  ('no', 0.0),
#  ('be', 0.0),
#  ('quit', 0.0),
#  ('new', 0.0),
#  ('ready', 0.0),
#  ('hide', 0.0),
#  ('do', 0.0),
#  ('find out', 0.0),
#  ('deep', 0.0),
#  ('think', 0.0),
#  ('soon', 0.0),
#  ('find', 0.0),
#  ('have', 0.0),
#  ('at first', 0.0),
#  ('do', 0.0),
#  ('old', 0.0),
#  ('work', 0.0),
#  ('bring', 0.0),
#  ('have got', 0.0),
#  ('passion', 0.0),
#  ('deep', 0.0),
#  ('earnest', 0.0),
#  ('purpose', 0.0),
#  ('have', 0.0),
#  ('sorely', 0.0),
#  ('pass', 0.0),
#  ('do', 0.0),
#  ('reach', 0.0),
#  ('mystery', 0.0),
#  ('bring', 0.0),
#  ('strange', 0.0),
#  ('swiftly', 0.0),
#  ('graven', 0.0),
#  ('make', 0.0),
#  ('establish', 0.0),
#  ('great', 0.0),
#  ('make', 0.0),
#  ('find', 0.0),
#  ('have', 0.0),
#  ('opportunity', 0.0),
#  ('breakfast', 0.0),
#  ('discovery', 0.0),
#  ('care', 0.0),
#  ('eager', 0.0),
#  ('come', 0.0),
#  ('result', 0.0),
#  ('second thought', 0.0),
#  ('obtain', 0.0),
#  ('new', 0.0),
#  ('quest', 0.0),
#  ('drive off', 0.0),
#  ...]

# %%
# Filter for -20 < sentiment <= -10
mild_negative = [
    (clemma, sentiment) for clemma, sentiment in concept_sentiment_words
    if -20 < sentiment <= -10
]

# Filter for 10 <= sentiment < 20
mild_positive = [
    (clemma, sentiment) for clemma, sentiment in concept_sentiment_words
    if 10 <= sentiment < 20
]

# Sort both lists by sentiment
mild_negative_sorted = sorted(mild_negative, key=lambda x: x[1])
mild_positive_sorted = sorted(mild_positive, key=lambda x: x[1])

# Show first few results
print("Mildly Negative Sentiment (-20 to -10):")
for clemma, sentiment in mild_negative_sorted:
    print(f"{clemma} → {sentiment}")

print("\nMildly Positive Sentiment (10 to 20):")
for clemma, sentiment in mild_positive_sorted:
    print(f"{clemma} → {sentiment}")
# Out:
# Mildly Negative Sentiment (-20 to -10):
# supreme → -19.5
#
# Mildly Positive Sentiment (10 to 20):
# occupy → 11.3
# think → 11.85
# sir → 12.0
# more → 13.0
# convenient → 19.0
